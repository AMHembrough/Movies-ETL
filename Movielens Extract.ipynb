# %%
import json
import pandas as pd
import numpy as np

# %%
file_dir = "C:/Users/hembroua/Columbia_Uni/Module 8/Movies-ETL/"

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
# First 5 records
kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 560    False                                                NaN        0
# 12599  False  {'id': 44215, 'name': 'Stargate SG-1 Collectio...  7000000
# 9836   False                                                NaN        0
# 36969  False                                                NaN        0
# 27152  False  {'id': 256287, 'name': 'Justice League (Animat...  3500000
#
#                                                   genres  \
# 560    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 12599  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 9836   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 36969  [{'id': 10769, 'name': 'Foreign'}, {'id': 53, ...
# 27152  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                                 homepage      id    imdb_id  \
# 560                                                  NaN   11800  tt0110623
# 12599                                                NaN   13001  tt0942903
# 9836                                                 NaN   52277  tt0281176
# 36969            http://nosmoking.erosentertainment.com/   36204  tt0995740
# 27152  http://www.warnerbros.com/justice-league-thron...  297556  tt3878542
#
#       original_language                      original_title  \
# 560                  en                   Naked in New York
# 12599                en          Stargate: The Ark of Truth
# 9836                 en                          Mávahlátur
# 36969                en                          No Smoking
# 27152                en  Justice League: Throne of Atlantis
#
#                                                 overview  ... release_date  \
# 560    Naked in New York begins in the car of grown u...  ...   1993-11-10
# 12599  SG-1 searches for an ancient weapon which coul...  ...   2008-03-11
# 9836   Post-war provincial Iceland: around 1950, Frey...  ...   2001-10-20
# 36969  A man fights against a tyrannical institution ...  ...   2007-10-26
# 27152  After the events of Justice League: War, Ocean...  ...   2015-01-27
#
#          revenue runtime                           spoken_languages    status  \
# 560          0.0    95.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 12599  8900000.0    97.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9836         0.0   102.0  [{'iso_639_1': 'is', 'name': 'Íslenska'}]  Released
# 36969        0.0   160.0    [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 27152        0.0    72.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 560                                                  NaN
# 12599  The lines have been drawn. The battle has been...
# 9836                                                 NaN
# 36969                                                NaN
# 27152                       Blood is thicker than water.
#
#                                     title  video vote_average vote_count
# 560                     Naked in New York  False          4.0        3.0
# 12599          Stargate: The Ark of Truth  False          6.9      143.0
# 9836               The Seagull's Laughter  False          6.4        7.0
# 36969                          No Smoking  False          6.0        7.0
# 27152  Justice League: Throne of Atlantis  False          6.5      222.0
#
# [5 rows x 24 columns]

# %%
# First 5 records
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 9954125   102587    55247     4.5  1241800499
# 18872964  196028      616     3.0   846020002
# 19768026  205422      344     2.5  1422388840
# 11927493  123677      593     5.0   962783398
# 25745214  267899     3635     3.0   962838882

# %%
def clean_movie(movie):
# Out:
#   File "<ipython-input-6-f878d9d01f82>", line 1
#     def clean_movie(movie):
#                            ^
# SyntaxError: unexpected EOF while parsing
